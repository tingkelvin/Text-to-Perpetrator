# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt/')
# Out:
# Mounted at /content/mnt/

# %%
batch_sizes = [256]
learning_rates = [3e-4, 4e-4, 5e-4]
for batch_size in batch_sizes:
    for learning_rate in learning_rates:
      # !python /content/mnt/MyDrive/Team-15/NLP/train.py -d partern6cat13subcat35 -b $batch_size -lr $learning_rate -g True -e 50 -tb True
# Out:
# Running GPU: Tesla T4
# Training Dataset: partern6cat13subcat35, batch size: 256, epochs: 50, learning rate: 0.0003
# Epoch 1: Train loss: 2.519817, Val loss: 2.403273, Val acc: 14.2%
# Model saved.
# Epoch 2: Train loss: 2.389917, Val loss: 2.336962, Val acc: 23.0%
# Model saved.
# Epoch 3: Train loss: 2.208708, Val loss: 1.947385, Val acc: 39.5%
# Model saved.
# Epoch 4: Train loss: 1.736554, Val loss: 1.314144, Val acc: 59.9%
# Model saved.
# Epoch 5: Train loss: 1.043372, Val loss: 0.413364, Val acc: 87.7%
# Model saved.
# Epoch 6: Train loss: 0.364695, Val loss: 0.152924, Val acc: 95.6%
# Model saved.
# Epoch 7: Train loss: 0.195920, Val loss: 0.096802, Val acc: 97.2%
# Model saved.
# Epoch 8: Train loss: 0.152087, Val loss: 0.073029, Val acc: 98.0%
# Model saved.
# Epoch 9: Train loss: 0.122387, Val loss: 0.056830, Val acc: 98.3%
# Model saved.
# Epoch 10: Train loss: 0.107561, Val loss: 0.054183, Val acc: 98.5%
# Model saved.
# ...

# %%
# !python /content/mnt/MyDrive/Team-15/NLP/train.py -d partern6cat13subcat35 -g True --train False -e 1
# Out:
# Running GPU: Tesla P100-PCIE-16GB
# Loading trained model on dataset partern6cat13subcat35...
# Test Accuracy:
# race: 100.0%, gender: 99.8%, hair_style:99.9%, hair_color: 100.0%, hair_len: 99.9%, top: 100.0%, top_color: 99.2%, bottom: 100.0%, bottom_color: 99.8%, footwear: 100.0%, footwear_color: 99.9%, accessory: 99.7%, accessory_color: 99.9%, Test avg loss: 0.005701

# %%
# !python /content/mnt/MyDrive/Team-15/NLP/test.py -m partern6cat13subcat35 -g True -t "black jacket"
# Out:
# race black
# gender male
# hair_style NA
# hair_color NA
# hair_len NA
# top jacket
# top_color black
# bottom NA
# bottom_color NA
# footwear boots
# footwear_color NA
# accessory NA
# accessory_color black
